# %% [markdown]
# # 02 - Variable Deep-Dive EDA
#
# This notebook profiles each variable with practical diagnostics:
# - type, missingness, uniqueness
# - distribution stats
# - outlier ratios for numeric features
# - top levels for categorical features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 200)
sns.set_theme(style='whitegrid')

# %%
df = pd.read_excel('../cars.xlsx')
print('shape:', df.shape)
df.head(2)
# Out:
# shape: (78025, 19)
#    Opportunity Number   Supplies Group     Supplies Subgroup     Region  \
# 0             1641984  Car Accessories  Exterior Accessories  Northwest
# 1             1658010  Car Accessories  Exterior Accessories    Pacific
#
#   Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0    Fields Sales                           76                Won
# 1        Reseller                           63               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
#
#   Client Size By Revenue (USD) Client Size By Employee Count  \
# 0                 More than 1M                 More than 25K
# 1                 250K to 500K                 More than 25K
#
#   Revenue From Client Past Two Years (USD) Competitor Type  \
# 0                          0 (No business)         Unknown
# 1                          0 (No business)         Unknown
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
#
#    Ratio Days Qualified To Total Days Deal Size Category (USD)
# 0                            0.154215              10K or less
# 1                            0.000000              10K or less

# %% [markdown]
# ## Variable inventory

# %%
rows = []
for c in df.columns:
    s = df[c]
    row = {
        'variable': c,
        'dtype': str(s.dtype),
        'missing_pct': round(s.isna().mean() * 100, 2),
        'n_unique': int(s.nunique(dropna=True)),
        'sample_values': ', '.join(map(str, s.dropna().astype(str).head(3).tolist()))
    }
    if pd.api.types.is_numeric_dtype(s):
        q1, q3 = s.quantile([0.25, 0.75])
        iqr = q3 - q1
        low, high = q1 - 1.5 * iqr, q3 + 1.5 * iqr
        row.update({
            'mean': float(s.mean()),
            'std': float(s.std()),
            'p01': float(s.quantile(0.01)),
            'p50': float(s.quantile(0.50)),
            'p99': float(s.quantile(0.99)),
            'outlier_pct_iqr': round((((s < low) | (s > high)).mean() * 100), 2)
        })
    rows.append(row)

var_profile = pd.DataFrame(rows).sort_values(['missing_pct', 'n_unique'], ascending=[False, False])
var_profile
# Out:
#                                     variable    dtype  missing_pct  n_unique  \
# 14                           Competitor Type      str        11.86         2
# 0                         Opportunity Number    int64         0.00     77829
# 16        Ratio Days Validated To Total Days  float64         0.00     13992
# 17        Ratio Days Qualified To Total Days  float64         0.00     10106
# 10                    Opportunity Amount USD    int64         0.00      9879
# 15       Ratio Days Identified To Total Days  float64         0.00      9786
# 8      Total Days Identified Through Closing    int64         0.00       156
# 9    Total Days Identified Through Qualified    int64         0.00       156
# 5                Elapsed Days In Sales Stage    int64         0.00       138
# 7                   Sales Stage Change Count    int64         0.00        22
# 2                          Supplies Subgroup      str         0.00        11
# 3                                     Region      str         0.00         7
# 18                  Deal Size Category (USD)      str         0.00         7
# 4                            Route To Market      str         0.00         5
# 11              Client Size By Revenue (USD)      str         0.00         5
# 12             Client Size By Employee Count      str         0.00         5
# 13  Revenue From Client Past Two Years (USD)      str         0.00         5
# 1                             Supplies Group      str         0.00         4
# 6                         Opportunity Result      str         0.00         2
#
#                                         sample_values          mean  \
# 14                          Unknown, Unknown, Unknown           NaN
# 0                           1641984, 1658010, 1674737  7.653429e+06
# 16                                 0.113985, 1.0, 0.0  4.883139e-01
# 17                                 0.154215, 0.0, 0.0  1.850478e-01
# 10                                         0, 0, 7750  9.163726e+04
# 15                                  0.69636, 0.0, 1.0  2.030631e-01
# 8                                        104, 163, 82  1.672836e+01
# 9                                        101, 163, 82  1.631435e+01
# 5                                          76, 63, 24  4.359535e+01
# 7                                            13, 2, 7  2.955732e+00
# 2   Exterior Accessories, Exterior Accessories, Mo...           NaN
# 3                         Northwest, Pacific, Pacific           NaN
# 18              10K or less, 10K or less, 10K or less           NaN
# 4                    Fields Sales, Reseller, Reseller           NaN
# 11           More than 1M, 250K to 500K, 100K or less           NaN
# 12           More than 25K, More than 25K, 1K or less           NaN
# 13  0 (No business), 0 (No business), 0 (No business)           NaN
# 1   Car Accessories, Car Accessories, Performance ...           NaN
# 6                                      Won, Loss, Won           NaN
#
#              std        p01          p50         p99  outlier_pct_iqr
# 14           NaN        NaN          NaN         NaN              NaN
# 0   1.054848e+06  5650940.8  7545569.000  9952303.76             0.18
# 16  4.480771e-01        0.0        0.448        1.00             0.00
# 17  3.402831e-01        0.0        0.000        1.00            19.16
# 10  1.331610e+05        0.0    49000.000   700000.00             9.32
# 15  3.649845e-01        0.0        0.000        1.00            19.20
# 8   1.672959e+01        0.0       12.000       74.00             3.47
# 9   1.656260e+01        0.0       12.000       73.00             3.29
# 5   2.658560e+01        0.0       43.000       91.00             0.01
# 7   1.497242e+00        1.0        3.000        8.00            11.97
# 2            NaN        NaN          NaN         NaN              NaN
# 3            NaN        NaN          NaN         NaN              NaN
# 18           NaN        NaN          NaN         NaN              NaN
# 4            NaN        NaN          NaN         NaN              NaN
# 11           NaN        NaN          NaN         NaN              NaN
# 12           NaN        NaN          NaN         NaN              NaN
# 13           NaN        NaN          NaN         NaN              NaN
# 1            NaN        NaN          NaN         NaN              NaN
# 6            NaN        NaN          NaN         NaN              NaN

# %%
var_profile.to_csv('../data/processed/variable_profile.csv', index=False)
print('saved: ../data/processed/variable_profile.csv')
# Out:
# saved: ../data/processed/variable_profile.csv

# %% [markdown]
# ## Numeric distributions

# %%
num_cols = df.select_dtypes(include='number').columns.tolist()
for col in num_cols:
    fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))
    sns.histplot(df[col].dropna(), bins=50, kde=True, ax=axes[0])
    axes[0].set_title(f'Hist: {col}')

    sns.boxplot(x=df[col], ax=axes[1])
    axes[1].set_title(f'Box: {col}')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Categorical distributions

# %%
cat_cols = df.select_dtypes(exclude='number').columns.tolist()
for col in cat_cols:
    vc = df[col].fillna('MISSING').value_counts().head(12)
    plt.figure(figsize=(10, 3.5))
    sns.barplot(x=vc.index.astype(str), y=vc.values)
    plt.title(f'Top levels: {col}')
    plt.xticks(rotation=30, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Target-focused quick view

# %%
print('Win/Loss distribution (%)')
print((df['Opportunity Result'].value_counts(normalize=True) * 100).round(2))

print('\nDeal Size Category distribution (%)')
print((df['Deal Size Category (USD)'].value_counts(normalize=True) * 100).round(2))

print('\nAmount summary')
print(df['Opportunity Amount USD'].describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]))
# Out:
# Win/Loss distribution (%)
# Opportunity Result
# Loss    77.41
# Won     22.59
# Name: proportion, dtype: float64
#
# Deal Size Category distribution (%)
# Deal Size Category (USD)
# 40K to 50K       23.16
# 10K to 20K       19.38
# 30K to 40K       17.47
# 10K or less      15.50
# 20K to 30K       15.34
# 50K to 60K        6.32
# More than 60K     2.82
# Name: proportion, dtype: float64
#
# Amount summary
# count      78025.000000
# mean       91637.260750
# std       133161.029156
# min            0.000000
# 1%             0.000000
# 5%          1192.800000
# 50%        49000.000000
# 95%       350000.000000
# 99%       700000.000000
# max      1000000.000000
# Name: Opportunity Amount USD, dtype: float64
